# %%
# !pip install spacy

# !python -m spacy download es_core_news_sm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: spacy in c:\users\sameer\appdata\roaming\python\python311\site-packages (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\programdata\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\programdata\anaconda3\lib\site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\programdata\anaconda3\lib\site-packages (from spacy) (1.10.8)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\programdata\anaconda3\lib\site-packages (from spacy) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\programdata\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.1)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting es-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.7.0/es_core_news_sm-3.7.0-py3-none-any.whl (12.9 MB)
#      ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.9 MB 217.9 kB/s eta 0:01:00
#      --------------------------------------- 0.0/12.9 MB 245.8 kB/s eta 0:00:53
#      --------------------------------------- 0.1/12.9 MB 435.7 kB/s eta 0:00:30
#      --------------------------------------- 0.1/12.9 MB 514.3 kB/s eta 0:00:25
#      --------------------------------------- 0.1/12.9 MB 514.3 kB/s eta 0:00:25
#      --------------------------------------- 0.1/12.9 MB 514.3 kB/s eta 0:00:25
#       -------------------------------------- 0.2/12.9 MB 464.2 kB/s eta 0:00:28
#       -------------------------------------- 0.2/12.9 MB 464.2 kB/s eta 0:00:28
#       -------------------------------------- 0.2/12.9 MB 464.2 kB/s eta 0:00:28
#       -------------------------------------- 0.2/12.9 MB 464.2 kB/s eta 0:00:28
#       -------------------------------------- 0.2/12.9 MB 464.2 kB/s eta 0:00:28
#       -------------------------------------- 0.2/12.9 MB 464.2 kB/s eta 0:00:28
#       -------------------------------------- 0.2/12.9 MB 335.5 kB/s eta 0:00:38
#       -------------------------------------- 0.2/12.9 MB 327.4 kB/s eta 0:00:39
#       -------------------------------------- 0.3/12.9 MB 395.9 kB/s eta 0:00:32
#      - ------------------------------------- 0.4/12.9 MB 488.2 kB/s eta 0:00:26
#      - ------------------------------------- 0.5/12.9 MB 582.4 kB/s eta 0:00:22
#      - ------------------------------------- 0.6/12.9 MB 620.3 kB/s eta 0:00:20
#      - ------------------------------------- 0.6/12.9 MB 620.3 kB/s eta 0:00:20
#      - ------------------------------------- 0.6/12.9 MB 620.3 kB/s eta 0:00:20
#      - ------------------------------------- 0.6/12.9 MB 614.8 kB/s eta 0:00:20
#      - ------------------------------------- 0.6/12.9 MB 614.8 kB/s eta 0:00:20
#      - ------------------------------------- 0.6/12.9 MB 614.8 kB/s eta 0:00:20
#      - ------------------------------------- 0.6/12.9 MB 614.8 kB/s eta 0:00:20
#      - ------------------------------------- 0.6/12.9 MB 614.8 kB/s eta 0:00:20
#      - ------------------------------------- 0.6/12.9 MB 501.5 kB/s eta 0:00:25
#      - ------------------------------------- 0.7/12.9 MB 497.4 kB/s eta 0:00:25
#      -- ------------------------------------ 0.7/12.9 MB 496.9 kB/s eta 0:00:25
#      -- ------------------------------------ 0.8/12.9 MB 538.6 kB/s eta 0:00:23
#      -- ------------------------------------ 0.8/12.9 MB 577.9 kB/s eta 0:00:21
#      -- ------------------------------------ 1.0/12.9 MB 628.1 kB/s eta 0:00:20
#      -- ------------------------------------ 1.0/12.9 MB 641.7 kB/s eta 0:00:19
#      -- ------------------------------------ 1.0/12.9 MB 641.7 kB/s eta 0:00:19
#      --- ----------------------------------- 1.0/12.9 MB 611.5 kB/s eta 0:00:20
#      --- ----------------------------------- 1.1/12.9 MB 655.1 kB/s eta 0:00:18
#      --- ----------------------------------- 1.1/12.9 MB 655.3 kB/s eta 0:00:18
#      --- ----------------------------------- 1.2/12.9 MB 695.3 kB/s eta 0:00:17
#      --- ----------------------------------- 1.3/12.9 MB 711.4 kB/s eta 0:00:17
#      ---- ---------------------------------- 1.4/12.9 MB 764.6 kB/s eta 0:00:15
#      ---- ---------------------------------- 1.6/12.9 MB 831.1 kB/s eta 0:00:14
#      ---- ---------------------------------- 1.6/12.9 MB 821.7 kB/s eta 0:00:14
#      ----- --------------------------------- 1.8/12.9 MB 863.5 kB/s eta 0:00:13
#      ----- --------------------------------- 1.9/12.9 MB 923.2 kB/s eta 0:00:12
#      ------ -------------------------------- 2.0/12.9 MB 973.1 kB/s eta 0:00:12
#      ------ --------------------------------- 2.2/12.9 MB 1.0 MB/s eta 0:00:11
#      ------ --------------------------------- 2.2/12.9 MB 1.0 MB/s eta 0:00:11
#      ------ --------------------------------- 2.2/12.9 MB 1.0 MB/s eta 0:00:11
#      ------- -------------------------------- 2.3/12.9 MB 1.0 MB/s eta 0:00:11
#      ------- -------------------------------- 2.4/12.9 MB 1.0 MB/s eta 0:00:11
#      ------- -------------------------------- 2.5/12.9 MB 1.0 MB/s eta 0:00:11
#      -------- ------------------------------- 2.6/12.9 MB 1.1 MB/s eta 0:00:10
#      -------- ------------------------------- 2.8/12.9 MB 1.1 MB/s eta 0:00:10
#      -------- ------------------------------- 2.8/12.9 MB 1.1 MB/s eta 0:00:10
#      --------- ------------------------------ 3.0/12.9 MB 1.2 MB/s eta 0:00:09
#      --------- ------------------------------ 3.2/12.9 MB 1.2 MB/s eta 0:00:08
#      ---------- ----------------------------- 3.3/12.9 MB 1.2 MB/s eta 0:00:08
#      ---------- ----------------------------- 3.5/12.9 MB 1.3 MB/s eta 0:00:08
#      ----------- ---------------------------- 3.7/12.9 MB 1.3 MB/s eta 0:00:07
#      ----------- ---------------------------- 3.8/12.9 MB 1.4 MB/s eta 0:00:07
#      ----------- ---------------------------- 3.9/12.9 MB 1.4 MB/s eta 0:00:07
#      ----------- ---------------------------- 3.9/12.9 MB 1.4 MB/s eta 0:00:07
#      ------------ --------------------------- 4.1/12.9 MB 1.4 MB/s eta 0:00:07
#      ------------ --------------------------- 4.1/12.9 MB 1.4 MB/s eta 0:00:07
#      ------------ --------------------------- 4.1/12.9 MB 1.4 MB/s eta 0:00:07
#      ------------ --------------------------- 4.1/12.9 MB 1.4 MB/s eta 0:00:07
#      ------------ --------------------------- 4.1/12.9 MB 1.4 MB/s eta 0:00:07
#      ------------ --------------------------- 4.1/12.9 MB 1.3 MB/s eta 0:00:07
#      ------------- -------------------------- 4.2/12.9 MB 1.3 MB/s eta 0:00:07
#      -------------- ------------------------- 4.5/12.9 MB 1.4 MB/s eta 0:00:07
#      -------------- ------------------------- 4.8/12.9 MB 1.4 MB/s eta 0:00:06
#      --------------- ------------------------ 5.0/12.9 MB 1.5 MB/s eta 0:00:06
#      ---------------- ----------------------- 5.2/12.9 MB 1.5 MB/s eta 0:00:05
#      ---------------- ----------------------- 5.4/12.9 MB 1.6 MB/s eta 0:00:05
#      ---------------- ----------------------- 5.4/12.9 MB 1.6 MB/s eta 0:00:05
#      ---------------- ----------------------- 5.4/12.9 MB 1.6 MB/s eta 0:00:05
#      ----------------- ---------------------- 5.7/12.9 MB 1.6 MB/s eta 0:00:05
#      ----------------- ---------------------- 5.7/12.9 MB 1.6 MB/s eta 0:00:05
#      ----------------- ---------------------- 5.7/12.9 MB 1.6 MB/s eta 0:00:05
#      ----------------- ---------------------- 5.7/12.9 MB 1.6 MB/s eta 0:00:05
#      ----------------- ---------------------- 5.7/12.9 MB 1.6 MB/s eta 0:00:05
#      ----------------- ---------------------- 5.7/12.9 MB 1.5 MB/s eta 0:00:05
#      ----------------- ---------------------- 5.8/12.9 MB 1.5 MB/s eta 0:00:05
#      ------------------ --------------------- 5.9/12.9 MB 1.5 MB/s eta 0:00:05
#      ------------------- -------------------- 6.2/12.9 MB 1.6 MB/s eta 0:00:05
#      ------------------- -------------------- 6.4/12.9 MB 1.6 MB/s eta 0:00:05
#      -------------------- ------------------- 6.7/12.9 MB 1.6 MB/s eta 0:00:04
#      -------------------- ------------------- 6.7/12.9 MB 1.6 MB/s eta 0:00:04
#      -------------------- ------------------- 6.7/12.9 MB 1.6 MB/s eta 0:00:04
#      -------------------- ------------------- 6.7/12.9 MB 1.6 MB/s eta 0:00:04
#      --------------------- ------------------ 7.1/12.9 MB 1.7 MB/s eta 0:00:04
#      ---------------------- ----------------- 7.2/12.9 MB 1.7 MB/s eta 0:00:04
#      ---------------------- ----------------- 7.4/12.9 MB 1.7 MB/s eta 0:00:04
#      ----------------------- ---------------- 7.7/12.9 MB 1.7 MB/s eta 0:00:03
#      ------------------------ --------------- 7.8/12.9 MB 1.8 MB/s eta 0:00:03
#      ------------------------- -------------- 8.2/12.9 MB 1.8 MB/s eta 0:00:03
#      ------------------------- -------------- 8.4/12.9 MB 1.8 MB/s eta 0:00:03
#      -------------------------- ------------- 8.6/12.9 MB 1.9 MB/s eta 0:00:03
#      --------------------------- ------------ 9.0/12.9 MB 1.9 MB/s eta 0:00:02
#      ---------------------------- ----------- 9.2/12.9 MB 2.0 MB/s eta 0:00:02
#      ----------------------------- ---------- 9.5/12.9 MB 2.0 MB/s eta 0:00:02
#      ----------------------------- ---------- 9.6/12.9 MB 2.0 MB/s eta 0:00:02
#      ----------------------------- ---------- 9.6/12.9 MB 2.0 MB/s eta 0:00:02
#      ------------------------------ --------- 9.7/12.9 MB 2.0 MB/s eta 0:00:02
#      ------------------------------- -------- 10.0/12.9 MB 2.1 MB/s eta 0:00:02
#      ------------------------------- -------- 10.1/12.9 MB 2.0 MB/s eta 0:00:02
#      -------------------------------- ------- 10.3/12.9 MB 2.1 MB/s eta 0:00:02
#      --------------------------------- ------ 10.7/12.9 MB 2.4 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.1/12.9 MB 2.8 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.1/12.9 MB 2.8 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.4/12.9 MB 3.0 MB/s eta 0:00:01
#      ------------------------------------ --- 11.8/12.9 MB 3.1 MB/s eta 0:00:01
#      ------------------------------------ --- 11.9/12.9 MB 3.1 MB/s eta 0:00:01
#      ------------------------------------- -- 12.2/12.9 MB 3.1 MB/s eta 0:00:01
#      -------------------------------------- - 12.5/12.9 MB 3.3 MB/s eta 0:00:01
#      -------------------------------------- - 12.5/12.9 MB 3.3 MB/s eta 0:00:01
#      -------------------------------------- - 12.5/12.9 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------------  12.9/12.9 MB 3.3 MB/s eta 0:00:01
#      ---------------------------------------- 12.9/12.9 MB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from es-core-news-sm==3.7.0) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.10.8)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.1.2)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.1.4)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\programdata\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\sameer\appdata\roaming\python\python311\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->es-core-news-sm==3.7.0) (2.1.1)
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.7.0
# [+] Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')

# %%
import spacy
nlp = spacy.load("es_core_news_sm")

# %%
doc = nlp("El gato está en la casa.")
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# El DET det
# gato NOUN nsubj
# está AUX ROOT
# en ADP case
# la DET det
# casa NOUN obl
# . PUNCT punct

# %%
text = """"La inteligencia artificial se fundó como disciplina académica en 1956 y, en los años transcurridos desde entonces, ha experimentado varias oleadas de optimismo,[5][6] seguidas de decepción y pérdida de financiación (conocido como "invierno de IA"),[7] [8] seguido de nuevos enfoques, éxito y financiación renovada.[6][9] La investigación de IA ha probado y descartado muchos enfoques diferentes desde su fundación, incluida la simulación del cerebro, el modelado de la resolución de problemas humanos, la lógica formal, las grandes bases de datos de conocimiento y la imitación del comportamiento animal. En las primeras décadas del siglo XXI, el aprendizaje automático altamente matemático-estadístico ha dominado el campo, y esta técnica ha demostrado ser muy exitosa, ayudando a resolver muchos problemas desafiantes en la industria y la academia.[9][10]

Los diversos subcampos de la investigación de IA se centran en objetivos particulares y el uso de herramientas particulares. Los objetivos tradicionales de la investigación de la IA incluyen el razonamiento, la representación del conocimiento, la planificación, el aprendizaje, el procesamiento del lenguaje natural, la percepción y la capacidad de mover y manipular objetos. -metas a plazo.[11] Para resolver estos problemas, los investigadores de IA han adaptado e integrado una amplia gama de técnicas de resolución de problemas, que incluyen búsqueda y optimización matemática, lógica formal, redes neuronales artificiales y métodos basados ​​en estadísticas, probabilidad y economía. AI también se basa en la informática, la psicología, la lingüística, la filosofía y muchos otros campos."""

# %%
import spacy
from spacy.lang.es.stop_words import STOP_WORDS
from string import punctuation

# %%
stopwords = list(STOP_WORDS) 
stopwords
# Out:
# ['consideró',
#  'sino',
#  'aunque',
#  'vuestra',
#  'haber',
#  'existe',
#  'explicó',
#  'va',
#  'final',
#  'mios',
#  'incluso',
#  'realizó',
#  'ciertas',
#  'ella',
#  'propia',
#  'usais',
#  'míos',
#  'también',
#  'segunda',
#  'consiguen',
#  'ha',
#  'seis',
#  'cierto',
#  'o',
#  'ni',
#  'decir',
#  'estas',
#  'primero',
#  'veces',
#  'nunca',
#  'sois',
#  'podrían',
#  'existen',
#  'llevar',
#  'algo',
#  'aseguró',
#  'esas',
#  'tuyo',
#  'vamos',
#  'podría',
#  'vuestros',
#  'ir',
#  'dónde',
#  'cuál',
#  'ser',
#  'pronto',
#  'sé',
#  'tengo',
#  'siendo',
#  'aquella',
#  'través',
#  'haceis',
#  'propios',
#  'aquí',
#  'parte',
#  'tambien',
#  'menos',
#  'consigo',
#  'podrias',
#  'cierta',
#  'conmigo',
#  'largo',
#  'tiene',
#  'vosotros',
#  'bueno',
#  'solo',
#  'podrán',
#  'otros',
#  'sí',
#  'una',
#  'quién',
#  'indicó',
#  'posible',
#  'podrá',
#  'con',
#  'serán',
#  'anterior',
#  'soy',
#  'ti',
#  'van',
#  'siempre',
#  'cada',
#  'algunas',
#  'cuántos',
#  'debe',
#  'otras',
#  'sobre',
#  'temprano',
#  'estaban',
#  'dio',
#  'diez',
#  'cual',
#  'estados',
#  'diferente',
#  'mismas',
#  'hasta',
#  'pasada',
#  'esa',
#  'varios',
#  'salvo',
#  'aquéllas',
#  'tuvo',
#  'alrededor',
#  'cuánto',
#  'pues',
#  'es',
#  'todavia',
#  'solas',
#  'se',
#  'trata',
#  'pudo',
#  'primeros',
#  'después',
#  'tampoco',
#  'poder',
#  'demasiado',
#  'tú',
#  'dos',
#  'solos',
#  'varias',
#  'sus',
#  'allí',
#  'pueden',
#  'claro',
#  'deprisa',
#  'diferentes',
#  'última',
#  'cuales',
#  'sigue',
#  'tuya',
#  'dicen',
#  'propio',
#  'tal',
#  'lo',
#  'proximo',
#  'usar',
#  'algunos',
#  'por',
#  'podriais',
#  'ello',
#  'estado',
#  'enseguida',
#  'buenos',
#  'antes',
#  'alguna',
#  'suyas',
#  'pasado',
#  'os',
#  'tres',
#  'tenido',
#  'verdad',
#  'lleva',
#  'mia',
#  'tendrá',
#  'grande',
#  'somos',
#  'grandes',
#  'sólo',
#  'mismos',
#  'tu',
#  'a',
#  'nuevas',
#  'consigues',
#  'han',
#  'usas',
#  'pocas',
#  'sabes',
#  'tendrán',
#  'mucho',
#  'podria',
#  'tarde',
#  'agregó',
#  'afirmó',
#  'estará',
#  'poca',
#  'sido',
#  'ningunas',
#  'solamente',
#  'cuenta',
#  'fueron',
#  'nuestra',
#  'mí',
#  'creo',
#  'dijo',
#  'sean',
#  'mas',
#  'ya',
#  'él',
#  'dan',
#  'algún',
#  'segundo',
#  'ésa',
#  'aún',
#  'eramos',
#  'nosotras',
#  'siete',
#  'era',
#  'ahora',
#  'paìs',
#  'hacerlo',
#  'nueve',
#  'ultimo',
#  'acuerdo',
#  'sería',
#  'primera',
#  'quedó',
#  'tus',
#  'gran',
#  'su',
#  'poco',
#  'llegó',
#  'sabe',
#  'buena',
#  'ésas',
#  'mías',
#  'alguno',
#  'según',
#  'mío',
#  'así',
#  'del',
#  'sea',
#  'alli',
#  'este',
#  'ellos',
#  'he',
#  'podeis',
#  'dar',
#  'la',
#  'segun',
#  'total',
#  'quiénes',
#  'haya',
#  'tuyos',
#  'todos',
#  'puede',
#  'contra',
#  'ambos',
#  'conseguimos',
#  'nuestro',
#  'sabemos',
#  'tuyas',
#  'dieron',
#  'nuestras',
#  'porque',
#  'usan',
#  'el',
#  'más',
#  'manifestó',
#  'verdadero',
#  'estos',
#  'ellas',
#  'peor',
#  'bastante',
#  'fin',
#  'tercera',
#  'aqui',
#  'fue',
#  'hace',
#  'saber',
#  'eran',
#  'manera',
#  'breve',
#  'yo',
#  'dejó',
#  'habían',
#  'pocos',
#  'primer',
#  'mal',
#  'todas',
#  'te',
#  'mis',
#  'hacia',
#  'fuimos',
#  'tanto',
#  'excepto',
#  'un',
#  'me',
#  'aquellos',
#  'cualquier',
#  'expresó',
#  'habla',
#  'fuera',
#  'ocho',
#  'suyo',
#  'nuevos',
#  'apenas',
#  'voy',
#  'pero',
#  'otro',
#  'están',
#  'ver',
#  'igual',
#  'será',
#  'quienes',
#  'ese',
#  'desde',
#  'teneis',
#  'verdadera',
#  'eso',
#  'hay',
#  'e',
#  'sola',
#  'vez',
#  'muchos',
#  'ése',
#  'mi',
#  'eres',
#  'detras',
#  'está',
#  'esto',
#  'tercero',
#  'hacer',
#  'mediante',
#  'medio',
#  'próximos',
#  'tenía',
#  'quizá',
#  'hemos',
#  'le',
#  'suyos',
#  'vuestras',
#  'entonces',
#  'realizado',
#  'ningún',
#  'ésos',
#  'aquélla',
#  'últimos',
#  'sin',
#  'supuesto',
#  'despues',
#  'todo',
#  'ciertos',
#  'delante',
#  'cuándo',
#  'último',
#  'aquel',
#  'durante',
#  'demás',
#  'dentro',
#  'consigue',
#  'repente',
#  'cuantas',
#  'usted',
#  'cómo',
#  'estan',
#  'todavía',
#  'éstos',
#  'podrian',
#  'quiere',
#  'al',
#  'siguiente',
#  'doce',
#  'nos',
#  'vosotras',
#  'vaya',
#  'realizar',
#  'próximo',
#  'asi',
#  'mayor',
#  'entre',
#  'otra',
#  'atras',
#  'nuestros',
#  'nueva',
#  'añadió',
#  'junto',
#  'suya',
#  'aquello',
#  'en',
#  'propias',
#  'arriba',
#  'ninguna',
#  'tienen',
#  'unos',
#  'mucha',
#  'cuanto',
#  'qeu',
#  'hablan',
#  'partir',
#  'donde',
#  'mientras',
#  'lado',
#  'para',
#  'uso',
#  'cuántas',
#  'esta',
#  'buenas',
#  'dijeron',
#  'nadie',
#  'u',
#  'da',
#  'hago',
#  'toda',
#  'debido',
#  'dicho',
#  'muy',
#  'buen',
#  'vuestro',
#  'dias',
#  'encima',
#  'ante',
#  'éstas',
#  'embargo',
#  'mio',
#  'cuando',
#  'respecto',
#  'adelante',
#  'tan',
#  'hacemos',
#  'estais',
#  'aun',
#  'queremos',
#  'como',
#  'ademas',
#  'días',
#  'quien',
#  'señaló',
#  'son',
#  'hoy',
#  'ahi',
#  'contigo',
#  'estar',
#  'poner',
#  'saben',
#  'sabeis',
#  'sera',
#  'hicieron',
#  'tras',
#  'cuanta',
#  'pueda',
#  'estoy',
#  'y',
#  'enfrente',
#  'qué',
#  'misma',
#  'eras',
#  'usa',
#  'estamos',
#  'nuevo',
#  'había',
#  'bien',
#  'conseguir',
#  'conocer',
#  'quizas',
#  'mía',
#  'hubo',
#  'ningunos',
#  'mencionó',
#  'podriamos',
#  'estaba',
#  'tener',
#  'deben',
#  'hecho',
#  'ahí',
#  'ustedes',
#  'fui',
#  'haces',
#  'hizo',
#  'que',
#  'éste',
#  'dado',
#  'mismo',
#  'podemos',
#  'aquellas',
#  'despacio',
#  'estuvo',
#  'cuáles',
#  'uno',
#  'usamos',
#  'menudo',
#  'cuantos',
#  'si',
#  'ninguno',
#  'tenemos',
#  'aproximadamente',
#  'habia',
#  'informó',
#  'nosotros',
#  'unas',
#  'quiza',
#  'detrás',
#  'encuentra',
#  'les',
#  'últimas',
#  'aquél',
#  'además',
#  'de',
#  'once',
#  'parece',
#  'casi',
#  'los',
#  'no',
#  'mejor',
#  'bajo',
#  'esos',
#  'cuatro',
#  'modo',
#  'aquéllos',
#  'cinco',
#  'considera',
#  'ésta',
#  'puedo',
#  'luego',
#  'informo',
#  'hacen',
#  'cuánta',
#  'muchas',
#  'tenga',
#  'vais',
#  'mias',
#  'comentó',
#  'haciendo',
#  'habrá',
#  'las',
#  'quizás',
#  'pesar',
#  'dice',
#  'debajo',
#  'día',
#  'dia',
#  'nada']

# %%
nlp = spacy.load('es_core_news_sm')

# %%
text
# Out:
# '"La inteligencia artificial se fundó como disciplina académica en 1956 y, en los años transcurridos desde entonces, ha experimentado varias oleadas de optimismo,[5][6] seguidas de decepción y pérdida de financiación (conocido como "invierno de IA"),[7] [8] seguido de nuevos enfoques, éxito y financiación renovada.[6][9] La investigación de IA ha probado y descartado muchos enfoques diferentes desde su fundación, incluida la simulación del cerebro, el modelado de la resolución de problemas humanos, la lógica formal, las grandes bases de datos de conocimiento y la imitación del comportamiento animal. En las primeras décadas del siglo XXI, el aprendizaje automático altamente matemático-estadístico ha dominado el campo, y esta técnica ha demostrado ser muy exitosa, ayudando a resolver muchos problemas desafiantes en la industria y la academia.[9][10]\n\nLos diversos subcampos de la investigación de IA se centran en objetivos particulares y el uso de herramientas particulares. Los objetivos tradicionales de la investigación de la IA incluyen el razonamiento, la representación del conocimiento, la planificación, el aprendizaje, el procesamiento del lenguaje natural, la percepción y la capacidad de mover y manipular objetos. -metas a plazo.[11] Para resolver estos problemas, los investigadores de IA han adaptado e integrado una amplia gama de técnicas de resolución de problemas, que incluyen búsqueda y optimización matemática, lógica formal, redes neuronales artificiales y métodos basados \u200b\u200ben estadísticas, probabilidad y economía. AI también se basa en la informática, la psicología, la lingüística, la filosofía y muchos otros campos.'

# %%
doc = nlp(text)
doc
# Out:
# "La inteligencia artificial se fundó como disciplina académica en 1956 y, en los años transcurridos desde entonces, ha experimentado varias oleadas de optimismo,[5][6] seguidas de decepción y pérdida de financiación (conocido como "invierno de IA"),[7] [8] seguido de nuevos enfoques, éxito y financiación renovada.[6][9] La investigación de IA ha probado y descartado muchos enfoques diferentes desde su fundación, incluida la simulación del cerebro, el modelado de la resolución de problemas humanos, la lógica formal, las grandes bases de datos de conocimiento y la imitación del comportamiento animal. En las primeras décadas del siglo XXI, el aprendizaje automático altamente matemático-estadístico ha dominado el campo, y esta técnica ha demostrado ser muy exitosa, ayudando a resolver muchos problemas desafiantes en la industria y la academia.[9][10]
#
# Los diversos subcampos de la investigación de IA se centran en objetivos particulares y el uso de herramientas particulares. Los objetivos tradicionales de la investigación de la IA incluyen el razonamiento, la representación del conocimiento, la planificación, el aprendizaje, el procesamiento del lenguaje natural, la percepción y la capacidad de mover y manipular objetos. -metas a plazo.[11] Para resolver estos problemas, los investigadores de IA han adaptado e integrado una amplia gama de técnicas de resolución de problemas, que incluyen búsqueda y optimización matemática, lógica formal, redes neuronales artificiales y métodos basados ​​en estadísticas, probabilidad y economía. AI también se basa en la informática, la psicología, la lingüística, la filosofía y muchos otros campos.

# %%
# lets get the tokens from text
tokens = [token.text for token in doc]
print(tokens) 
#when we execute everythihg we created tokens from the text & not removed any of the stopwords & didnt cleaned the data
# Out:
# ['"', 'La', 'inteligencia', 'artificial', 'se', 'fundó', 'como', 'disciplina', 'académica', 'en', '1956', 'y', ',', 'en', 'los', 'años', 'transcurridos', 'desde', 'entonces', ',', 'ha', 'experimentado', 'varias', 'oleadas', 'de', 'optimismo,[5][6', ']', 'seguidas', 'de', 'decepción', 'y', 'pérdida', 'de', 'financiación', '(', 'conocido', 'como', '"', 'invierno', 'de', 'IA"),[7', ']', '[', '8', ']', 'seguido', 'de', 'nuevos', 'enfoques', ',', 'éxito', 'y', 'financiación', 'renovada.[6][9', ']', 'La', 'investigación', 'de', 'IA', 'ha', 'probado', 'y', 'descartado', 'muchos', 'enfoques', 'diferentes', 'desde', 'su', 'fundación', ',', 'incluida', 'la', 'simulación', 'del', 'cerebro', ',', 'el', 'modelado', 'de', 'la', 'resolución', 'de', 'problemas', 'humanos', ',', 'la', 'lógica', 'formal', ',', 'las', 'grandes', 'bases', 'de', 'datos', 'de', 'conocimiento', 'y', 'la', 'imitación', 'del', 'comportamiento', 'animal', '.', 'En', 'las', 'primeras', 'décadas', 'del', 'siglo', 'XXI', ',', 'el', 'aprendizaje', 'automático', 'altamente', 'matemático-estadístico', 'ha', 'dominado', 'el', 'campo', ',', 'y', 'esta', 'técnica', 'ha', 'demostrado', 'ser', 'muy', 'exitosa', ',', 'ayudando', 'a', 'resolver', 'muchos', 'problemas', 'desafiantes', 'en', 'la', 'industria', 'y', 'la', 'academia.[9][10', ']', '\n\n', 'Los', 'diversos', 'subcampos', 'de', 'la', 'investigación', 'de', 'IA', 'se', 'centran', 'en', 'objetivos', 'particulares', 'y', 'el', 'uso', 'de', 'herramientas', 'particulares', '.', 'Los', 'objetivos', 'tradicionales', 'de', 'la', 'investigación', 'de', 'la', 'IA', 'incluyen', 'el', 'razonamiento', ',', 'la', 'representación', 'del', 'conocimiento', ',', 'la', 'planificación', ',', 'el', 'aprendizaje', ',', 'el', 'procesamiento', 'del', 'lenguaje', 'natural', ',', 'la', 'percepción', 'y', 'la', 'capacidad', 'de', 'mover', 'y', 'manipular', 'objetos', '.', '-metas', 'a', 'plazo.[11', ']', 'Para', 'resolver', 'estos', 'problemas', ',', 'los', 'investigadores', 'de', 'IA', 'han', 'adaptado', 'e', 'integrado', 'una', 'amplia', 'gama', 'de', 'técnicas', 'de', 'resolución', 'de', 'problemas', ',', 'que', 'incluyen', 'búsqueda', 'y', 'optimización', 'matemática', ',', 'lógica', 'formal', ',', 'redes', 'neuronales', 'artificiales', 'y', 'métodos', 'basados', '\u200b\u200ben', 'estadísticas', ',', 'probabilidad', 'y', 'economía', '.', 'AI', 'también', 'se', 'basa', 'en', 'la', 'informática', ',', 'la', 'psicología', ',', 'la', 'lingüística', ',', 'la', 'filosofía', 'y', 'muchos', 'otros', 'campos', '.']

# %%
punctuation # also called as noisy characters
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
#we have to calcualte the freaquency of each and every word, how many time word is repetation in text 

word_frequencies = {}

for word in doc:
    if word.text.lower() not in stopwords:
        if word.text.lower() not in punctuation:
            if word.text not in word_frequencies.keys():
                word_frequencies[word.text] = 1
            else:
                word_frequencies[word.text] += 1

# %%
word_frequencies
#print(word_frequencies)
# Out:
# {'inteligencia': 1,
#  'artificial': 1,
#  'fundó': 1,
#  'disciplina': 1,
#  'académica': 1,
#  '1956': 1,
#  'años': 1,
#  'transcurridos': 1,
#  'experimentado': 1,
#  'oleadas': 1,
#  'optimismo,[5][6': 1,
#  'seguidas': 1,
#  'decepción': 1,
#  'pérdida': 1,
#  'financiación': 2,
#  'conocido': 1,
#  'invierno': 1,
#  'IA"),[7': 1,
#  '8': 1,
#  'seguido': 1,
#  'enfoques': 2,
#  'éxito': 1,
#  'renovada.[6][9': 1,
#  'investigación': 3,
#  'IA': 4,
#  'probado': 1,
#  'descartado': 1,
#  'fundación': 1,
#  'incluida': 1,
#  'simulación': 1,
#  'cerebro': 1,
#  'modelado': 1,
#  'resolución': 2,
#  'problemas': 4,
#  'humanos': 1,
#  'lógica': 2,
#  'formal': 2,
#  'bases': 1,
#  'datos': 1,
#  'conocimiento': 2,
#  'imitación': 1,
#  'comportamiento': 1,
#  'animal': 1,
#  'primeras': 1,
#  'décadas': 1,
#  'siglo': 1,
#  'XXI': 1,
#  'aprendizaje': 2,
#  'automático': 1,
#  'altamente': 1,
#  'matemático-estadístico': 1,
#  'dominado': 1,
#  'campo': 1,
#  'técnica': 1,
#  'demostrado': 1,
#  'exitosa': 1,
#  'ayudando': 1,
#  'resolver': 2,
#  'desafiantes': 1,
#  'industria': 1,
#  'academia.[9][10': 1,
#  '\n\n': 1,
#  'diversos': 1,
#  'subcampos': 1,
#  'centran': 1,
#  'objetivos': 2,
#  'particulares': 2,
#  'herramientas': 1,
#  'tradicionales': 1,
#  'incluyen': 2,
#  'razonamiento': 1,
#  'representación': 1,
#  'planificación': 1,
#  'procesamiento': 1,
#  'lenguaje': 1,
#  'natural': 1,
#  'percepción': 1,
#  'capacidad': 1,
#  'mover': 1,
#  'manipular': 1,
#  'objetos': 1,
#  '-metas': 1,
#  'plazo.[11': 1,
#  'investigadores': 1,
#  'adaptado': 1,
#  'integrado': 1,
#  'amplia': 1,
#  'gama': 1,
#  'técnicas': 1,
#  'búsqueda': 1,
#  'optimización': 1,
#  'matemática': 1,
#  'redes': 1,
#  'neuronales': 1,
#  'artificiales': 1,
#  'métodos': 1,
#  'basados': 1,
#  '\u200b\u200ben': 1,
#  'estadísticas': 1,
#  'probabilidad': 1,
#  'economía': 1,
#  'AI': 1,
#  'basa': 1,
#  'informática': 1,
#  'psicología': 1,
#  'lingüística': 1,
#  'filosofía': 1,
#  'campos': 1}

# %%
max_frequency = max(word_frequencies.values())
max_frequency
# Out:
# 4

# %%
#to get normalized/weighted frequencies you should devide all frequencies with 11
for word in word_frequencies.keys():
    word_frequencies[word] = word_frequencies[word]/max_frequency

# %%
#print(word_frequencies)
word_frequencies
#this is the normalized frequencies of each word
# Out:
# {'inteligencia': 0.25,
#  'artificial': 0.25,
#  'fundó': 0.25,
#  'disciplina': 0.25,
#  'académica': 0.25,
#  '1956': 0.25,
#  'años': 0.25,
#  'transcurridos': 0.25,
#  'experimentado': 0.25,
#  'oleadas': 0.25,
#  'optimismo,[5][6': 0.25,
#  'seguidas': 0.25,
#  'decepción': 0.25,
#  'pérdida': 0.25,
#  'financiación': 0.5,
#  'conocido': 0.25,
#  'invierno': 0.25,
#  'IA"),[7': 0.25,
#  '8': 0.25,
#  'seguido': 0.25,
#  'enfoques': 0.5,
#  'éxito': 0.25,
#  'renovada.[6][9': 0.25,
#  'investigación': 0.75,
#  'IA': 1.0,
#  'probado': 0.25,
#  'descartado': 0.25,
#  'fundación': 0.25,
#  'incluida': 0.25,
#  'simulación': 0.25,
#  'cerebro': 0.25,
#  'modelado': 0.25,
#  'resolución': 0.5,
#  'problemas': 1.0,
#  'humanos': 0.25,
#  'lógica': 0.5,
#  'formal': 0.5,
#  'bases': 0.25,
#  'datos': 0.25,
#  'conocimiento': 0.5,
#  'imitación': 0.25,
#  'comportamiento': 0.25,
#  'animal': 0.25,
#  'primeras': 0.25,
#  'décadas': 0.25,
#  'siglo': 0.25,
#  'XXI': 0.25,
#  'aprendizaje': 0.5,
#  'automático': 0.25,
#  'altamente': 0.25,
#  'matemático-estadístico': 0.25,
#  'dominado': 0.25,
#  'campo': 0.25,
#  'técnica': 0.25,
#  'demostrado': 0.25,
#  'exitosa': 0.25,
#  'ayudando': 0.25,
#  'resolver': 0.5,
#  'desafiantes': 0.25,
#  'industria': 0.25,
#  'academia.[9][10': 0.25,
#  '\n\n': 0.25,
#  'diversos': 0.25,
#  'subcampos': 0.25,
#  'centran': 0.25,
#  'objetivos': 0.5,
#  'particulares': 0.5,
#  'herramientas': 0.25,
#  'tradicionales': 0.25,
#  'incluyen': 0.5,
#  'razonamiento': 0.25,
#  'representación': 0.25,
#  'planificación': 0.25,
#  'procesamiento': 0.25,
#  'lenguaje': 0.25,
#  'natural': 0.25,
#  'percepción': 0.25,
#  'capacidad': 0.25,
#  'mover': 0.25,
#  'manipular': 0.25,
#  'objetos': 0.25,
#  '-metas': 0.25,
#  'plazo.[11': 0.25,
#  'investigadores': 0.25,
#  'adaptado': 0.25,
#  'integrado': 0.25,
#  'amplia': 0.25,
#  'gama': 0.25,
#  'técnicas': 0.25,
#  'búsqueda': 0.25,
#  'optimización': 0.25,
#  'matemática': 0.25,
#  'redes': 0.25,
#  'neuronales': 0.25,
#  'artificiales': 0.25,
#  'métodos': 0.25,
#  'basados': 0.25,
#  '\u200b\u200ben': 0.25,
#  'estadísticas': 0.25,
#  'probabilidad': 0.25,
#  'economía': 0.25,
#  'AI': 0.25,
#  'basa': 0.25,
#  'informática': 0.25,
#  'psicología': 0.25,
#  'lingüística': 0.25,
#  'filosofía': 0.25,
#  'campos': 0.25}

# %%
sentence_tokens = [sent for sent in doc.sents]
sentence_tokens
# Out:
# ["La inteligencia artificial se fundó como disciplina académica en 1956 y, en los años transcurridos desde entonces, ha experimentado varias oleadas de optimismo,[5][6] seguidas de decepción y pérdida de financiación (conocido como "invierno de IA"),[7] [8] seguido de nuevos enfoques, éxito y financiación renovada.[6][9] La investigación de IA ha probado y descartado muchos enfoques diferentes desde su fundación, incluida la simulación del cerebro, el modelado de la resolución de problemas humanos, la lógica formal, las grandes bases de datos de conocimiento y la imitación del comportamiento animal.,
#  En las primeras décadas del siglo XXI, el aprendizaje automático altamente matemático-estadístico ha dominado el campo, y esta técnica ha demostrado ser muy exitosa, ayudando a resolver muchos problemas desafiantes en la industria y la academia.[9][10]
#
#  Los diversos subcampos de la investigación de IA se centran en objetivos particulares y el uso de herramientas particulares.,
#  Los objetivos tradicionales de la investigación de la IA incluyen el razonamiento, la representación del conocimiento, la planificación, el aprendizaje, el procesamiento del lenguaje natural, la percepción y la capacidad de mover y manipular objetos.,
#  -metas a plazo.[11] Para resolver estos problemas, los investigadores de IA han adaptado e integrado una amplia gama de técnicas de resolución de problemas, que incluyen búsqueda y optimización matemática, lógica formal, redes neuronales artificiales y métodos basados ​​en estadísticas, probabilidad y economía.,
#  AI también se basa en la informática, la psicología, la lingüística, la filosofía y muchos otros campos.]

# %%
len(sentence_tokens)
# Out:
# 5

# %%
# we are going to calculate the sentence score, to calculate the sentence score 
sentence_scores = {}

for sent in sentence_tokens:
    for word in sent:
        if word.text.lower() in word_frequencies.keys():
            if sent not in sentence_scores.keys():
                sentence_scores[sent] = word_frequencies[word.text.lower()]
            else:
                sentence_scores[sent] += word_frequencies[word.text.lower()]

# %%
sentence_scores
# Out:
# {"La inteligencia artificial se fundó como disciplina académica en 1956 y, en los años transcurridos desde entonces, ha experimentado varias oleadas de optimismo,[5][6] seguidas de decepción y pérdida de financiación (conocido como "invierno de IA"),[7] [8] seguido de nuevos enfoques, éxito y financiación renovada.[6][9] La investigación de IA ha probado y descartado muchos enfoques diferentes desde su fundación, incluida la simulación del cerebro, el modelado de la resolución de problemas humanos, la lógica formal, las grandes bases de datos de conocimiento y la imitación del comportamiento animal.: 14.0,
#  En las primeras décadas del siglo XXI, el aprendizaje automático altamente matemático-estadístico ha dominado el campo, y esta técnica ha demostrado ser muy exitosa, ayudando a resolver muchos problemas desafiantes en la industria y la academia.[9][10]
#
#  Los diversos subcampos de la investigación de IA se centran en objetivos particulares y el uso de herramientas particulares.: 9.25,
#  Los objetivos tradicionales de la investigación de la IA incluyen el razonamiento, la representación del conocimiento, la planificación, el aprendizaje, el procesamiento del lenguaje natural, la percepción y la capacidad de mover y manipular objetos.: 5.75,
#  -metas a plazo.[11] Para resolver estos problemas, los investigadores de IA han adaptado e integrado una amplia gama de técnicas de resolución de problemas, que incluyen búsqueda y optimización matemática, lógica formal, redes neuronales artificiales y métodos basados ​​en estadísticas, probabilidad y economía.: 9.5,
#  AI también se basa en la informática, la psicología, la lingüística, la filosofía y muchos otros campos.: 1.5}

# %%
#lets say our case study was 30% sentence with maximum scores
from heapq import nlargest

# %%
select_length = int(len(sentence_tokens)*0.3)
select_length
# Out:
# 1

# %%
#we have to select maximum 4 sentences out of all sentences 
summary = nlargest(select_length,sentence_scores, key = sentence_scores.get)

# %%
summary
# Out:
# ["La inteligencia artificial se fundó como disciplina académica en 1956 y, en los años transcurridos desde entonces, ha experimentado varias oleadas de optimismo,[5][6] seguidas de decepción y pérdida de financiación (conocido como "invierno de IA"),[7] [8] seguido de nuevos enfoques, éxito y financiación renovada.[6][9] La investigación de IA ha probado y descartado muchos enfoques diferentes desde su fundación, incluida la simulación del cerebro, el modelado de la resolución de problemas humanos, la lógica formal, las grandes bases de datos de conocimiento y la imitación del comportamiento animal.]

# %%
select_length = int(len(sentence_tokens)*0.4)
select_length
# Out:
# 2

# %%
#we have to select maximum 5 sentences out of all sentences 
summary = nlargest(select_length,sentence_scores, key = sentence_scores.get)

# %%
summary
# Out:
# ["La inteligencia artificial se fundó como disciplina académica en 1956 y, en los años transcurridos desde entonces, ha experimentado varias oleadas de optimismo,[5][6] seguidas de decepción y pérdida de financiación (conocido como "invierno de IA"),[7] [8] seguido de nuevos enfoques, éxito y financiación renovada.[6][9] La investigación de IA ha probado y descartado muchos enfoques diferentes desde su fundación, incluida la simulación del cerebro, el modelado de la resolución de problemas humanos, la lógica formal, las grandes bases de datos de conocimiento y la imitación del comportamiento animal.,
#  -metas a plazo.[11] Para resolver estos problemas, los investigadores de IA han adaptado e integrado una amplia gama de técnicas de resolución de problemas, que incluyen búsqueda y optimización matemática, lógica formal, redes neuronales artificiales y métodos basados ​​en estadísticas, probabilidad y economía.]

# %%
sentence_scores
# Out:
# {"La inteligencia artificial se fundó como disciplina académica en 1956 y, en los años transcurridos desde entonces, ha experimentado varias oleadas de optimismo,[5][6] seguidas de decepción y pérdida de financiación (conocido como "invierno de IA"),[7] [8] seguido de nuevos enfoques, éxito y financiación renovada.[6][9] La investigación de IA ha probado y descartado muchos enfoques diferentes desde su fundación, incluida la simulación del cerebro, el modelado de la resolución de problemas humanos, la lógica formal, las grandes bases de datos de conocimiento y la imitación del comportamiento animal.: 14.0,
#  En las primeras décadas del siglo XXI, el aprendizaje automático altamente matemático-estadístico ha dominado el campo, y esta técnica ha demostrado ser muy exitosa, ayudando a resolver muchos problemas desafiantes en la industria y la academia.[9][10]
#
#  Los diversos subcampos de la investigación de IA se centran en objetivos particulares y el uso de herramientas particulares.: 9.25,
#  Los objetivos tradicionales de la investigación de la IA incluyen el razonamiento, la representación del conocimiento, la planificación, el aprendizaje, el procesamiento del lenguaje natural, la percepción y la capacidad de mover y manipular objetos.: 5.75,
#  -metas a plazo.[11] Para resolver estos problemas, los investigadores de IA han adaptado e integrado una amplia gama de técnicas de resolución de problemas, que incluyen búsqueda y optimización matemática, lógica formal, redes neuronales artificiales y métodos basados ​​en estadísticas, probabilidad y economía.: 9.5,
#  AI también se basa en la informática, la psicología, la lingüística, la filosofía y muchos otros campos.: 1.5}

# %%
print(summary)
# Out:
# ["La inteligencia artificial se fundó como disciplina académica en 1956 y, en los años transcurridos desde entonces, ha experimentado varias oleadas de optimismo,[5][6] seguidas de decepción y pérdida de financiación (conocido como "invierno de IA"),[7] [8] seguido de nuevos enfoques, éxito y financiación renovada.[6][9] La investigación de IA ha probado y descartado muchos enfoques diferentes desde su fundación, incluida la simulación del cerebro, el modelado de la resolución de problemas humanos, la lógica formal, las grandes bases de datos de conocimiento y la imitación del comportamiento animal., -metas a plazo.[11] Para resolver estos problemas, los investigadores de IA han adaptado e integrado una amplia gama de técnicas de resolución de problemas, que incluyen búsqueda y optimización matemática, lógica formal, redes neuronales artificiales y métodos basados ​​en estadísticas, probabilidad y economía.]

# %%
La inteligencia artificial se fundó como disciplina académica en 1956 y, en los años transcurridos desde entonces, ha experimentado varias oleadas de optimismo,[5][6] seguidas de decepción y pérdida de financiación (conocido como "invierno de IA"),[7] [8] seguido de nuevos enfoques, éxito y financiación renovada.[6][9] La investigación de IA ha probado y descartado muchos enfoques diferentes desde su fundación, incluida la simulación del cerebro, el modelado de la resolución de problemas humanos, la lógica formal, las grandes bases de datos de conocimiento y la imitación del comportamiento animal. En las primeras décadas del siglo XXI, el aprendizaje automático altamente matemático-estadístico ha dominado el campo, y esta técnica ha demostrado ser muy exitosa, ayudando a resolver muchos problemas desafiantes en la industria y la academia.
Los diversos subcampos de la investigación de IA se centran en objetivos particulares y el uso de herramientas particulares. Los objetivos tradicionales de la investigación de la IA incluyen el razonamiento, la representación del conocimiento, la planificación, el aprendizaje, el procesamiento del lenguaje natural, la percepción y la capacidad de mover y manipular objetos. -metas a plazo.[11] Para resolver estos problemas, los investigadores de IA han adaptado e integrado una amplia gama de técnicas de resolución de problemas, que incluyen búsqueda y optimización matemática, lógica formal, redes neuronales artificiales y métodos basados ​​en estadísticas, probabilidad y economía. AI también se basa en la informática, la psicología, la lingüística, la filosofía y muchos otros campos.
