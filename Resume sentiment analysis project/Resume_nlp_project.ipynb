# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Resume.csv')

# %%
df.head(10)
# Out:
#        Category                                             Resume
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
# 5  Data Science  SKILLS C Basics, IOT, Python, MATLAB, Data Sci...
# 6  Data Science  Skills â¢ Python â¢ Tableau â¢ Data Visuali...
# 7  Data Science  Education Details \r\n B.Tech   Rayat and Bahr...
# 8  Data Science  Personal Skills â¢ Ability to quickly grasp t...
# 9  Data Science  Expertise â Data and Quantitative Analysis â...

# %%
df.shape
# Out:
# (962, 2)

# %%
df['Resume'][0]
# Out:
# 'Skills * Programming Languages: Python (pandas, numpy, scipy, scikit-learn, matplotlib), Sql, Java, JavaScript/JQuery. * Machine learning: Regression, SVM, NaÃ¯ve Bayes, KNN, Random Forest, Decision Trees, Boosting techniques, Cluster Analysis, Word Embedding, Sentiment Analysis, Natural Language processing, Dimensionality reduction, Topic Modelling (LDA, NMF), PCA & Neural Nets. * Database Visualizations: Mysql, SqlServer, Cassandra, Hbase, ElasticSearch D3.js, DC.js, Plotly, kibana, matplotlib, ggplot, Tableau. * Others: Regular Expression, HTML, CSS, Angular 6, Logstash, Kafka, Python Flask, Git, Docker, computer vision - Open CV and understanding of Deep learning.Education Details \r\n\r\nData Science Assurance Associate \r\n\r\nData Science Assurance Associate - Ernst & Young LLP\r\nSkill Details \r\nJAVASCRIPT- Exprience - 24 months\r\njQuery- Exprience - 24 months\r\nPython- Exprience - 24 monthsCompany Details \r\ncompany - Ernst & Young LLP\r\ndescription - Fraud Investigat
# ...

# %%
print(df['Resume'][0])
# Out:
# Skills * Programming Languages: Python (pandas, numpy, scipy, scikit-learn, matplotlib), Sql, Java, JavaScript/JQuery. * Machine learning: Regression, SVM, NaÃ¯ve Bayes, KNN, Random Forest, Decision Trees, Boosting techniques, Cluster Analysis, Word Embedding, Sentiment Analysis, Natural Language processing, Dimensionality reduction, Topic Modelling (LDA, NMF), PCA & Neural Nets. * Database Visualizations: Mysql, SqlServer, Cassandra, Hbase, ElasticSearch D3.js, DC.js, Plotly, kibana, matplotlib, ggplot, Tableau. * Others: Regular Expression, HTML, CSS, Angular 6, Logstash, Kafka, Python Flask, Git, Docker, computer vision - Open CV and understanding of Deep learning.Education Details
#
# Data Science Assurance Associate
#
# Data Science Assurance Associate - Ernst & Young LLP
# Skill Details
# JAVASCRIPT- Exprience - 24 months
# jQuery- Exprience - 24 months
# Python- Exprience - 24 monthsCompany Details
# company - Ernst & Young LLP
# ...

# %%
df['Category'].value_counts()
# Out:
# Category
# Java Developer               84
# Testing                      70
# DevOps Engineer              55
# Python Developer             48
# Web Designing                45
# HR                           44
# Hadoop                       42
# Blockchain                   40
# ETL Developer                40
# Operations Manager           40
# Data Science                 40
# Sales                        40
# Mechanical Engineer          40
# Arts                         36
# Database                     33
# Electrical Engineering       30
# Health and fitness           30
# PMO                          30
# Business Analyst             28
# DotNet Developer             28
# Automation Testing           26
# Network Security Engineer    25
# SAP Developer                24
# Civil Engineer               24
# Advocate                     20
# Name: count, dtype: int64

# %%
# Data Cleaning
'''
1. url
2. hashtags
3. mentions
4. special letters
5. punctuations
'''
# Out:
# '\n1. url\n2. hashtags\n3. mentions\n4. special letters\n5. punctuations\n'

# %%
import re

def cleanResume(txt):
  cleantext = re.sub("http\S+\s"," ",txt)
  cleantext = re.sub("#\S+\s"," ",cleantext)
  cleantext = re.sub("RT|CC"," ",cleantext)
  cleantext = re.sub("@\S+\s"," ",cleantext)
  cleantext = re.sub('[%s]'% re.escape("""!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"""), ' ', cleantext)
  return cleantext

# %%
df['Resume'] = df['Resume'].apply(lambda x:cleanResume(x))

# %%
print(df['Resume'][0])
# Out:
# Skills   Programming Languages  Python  pandas  numpy  scipy  scikit learn  matplotlib   Sql  Java  JavaScript JQuery    Machine learning  Regression  SVM  NaÃ¯ve Bayes  KNN  Random Forest  Decision Trees  Boosting techniques  Cluster Analysis  Word Embedding  Sentiment Analysis  Natural Language processing  Dimensionality reduction  Topic Modelling  LDA  NMF   PCA   Neural Nets    Database Visualizations  Mysql  SqlServer  Cassandra  Hbase  ElasticSearch D3 js  DC js  Plotly  kibana  matplotlib  ggplot  Tableau    Others  Regular Expression  HTML  CSS  Angular 6  Logstash  Kafka  Python Flask  Git  Docker  computer vision   Open CV and understanding of Deep learning Education Details
#
# Data Science Assurance Associate
#
# Data Science Assurance Associate   Ernst   Young LLP
# Skill Details
# JAVASCRIPT  Exprience   24 months
# jQuery  Exprience   24 months
# Python  Exprience   24 monthsCompany Details
# company   Ernst   Young LLP
# ...

# %%
print(df['Resume'][1])
# Out:
# Education Details
# May 2013 to May 2017 B E   UIT RGPV
# Data Scientist
#
# Data Scientist   Matelabs
# Skill Details
# Python  Exprience   Less than 1 year months
# Statsmodels  Exprience   12 months
# AWS  Exprience   Less than 1 year months
# Machine learning  Exprience   Less than 1 year months
# Sklearn  Exprience   Less than 1 year months
# Scipy  Exprience   Less than 1 year months
# Keras  Exprience   Less than 1 year monthsCompany Details
# company   Matelabs
# description   ML Platform for business professionals  dummies and enthusiasts
# 60 A Koramangala 5th block
# Achievements Tasks behind sukh sagar  Bengaluru
# India                               Developed and deployed auto preprocessing steps of machine learning mainly missing value
# treatment  outlier detection  encoding  scaling  feature selection and dimensionality reduction
# Deployed automated classification and regression model
# linkedin com in aditya rathore
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Category'] = le.fit_transform(df['Category'])

# %%
df.head()
# Out:
#    Category                                             Resume
# 0         6  Skills   Programming Languages  Python  pandas...
# 1         6  Education Details \r\nMay 2013 to May 2017 B E...
# 2         6  Areas of Interest Deep Learning  Control Syste...
# 3         6  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4         6  Education Details \r\n MCA   YMCAUST   Faridab...

# %%
df.tail()
# Out:
#      Category                                             Resume
# 957        23  Computer Skills  â¢ Proficient in MS office  ...
# 958        23  â Willingness to accept the challenges  â ...
# 959        23  PERSONAL SKILLS â¢ Quick learner  â¢ Eagerne...
# 960        23  COMPUTER SKILLS   SOFTWARE KNOWLEDGE MS Power ...
# 961        23  Skill Set OS Windows XP 7 8 8 1 10 Database MY...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words='english')
tfidf.fit(df['Resume'])
# Out:
# TfidfVectorizer(stop_words='english')

# %%
requiredtext = tfidf.transform(df['Resume'])

# %%
print(requiredtext)
# Out:
#   (0, 7354)	0.07791838313618284
#   (0, 7342)	0.013773935617086773
#   (0, 7289)	0.015623956436878255
#   (0, 7285)	0.08208089215094955
#   (0, 7284)	0.04529282661236908
#   (0, 7283)	0.07363448111591957
#   (0, 7140)	0.09058565322473816
#   (0, 7127)	0.03209300708360493
#   (0, 7057)	0.03563467529338486
#   (0, 7053)	0.07917736197354959
#   (0, 7040)	0.015070726656576475
#   (0, 7016)	0.04529282661236908
#   (0, 6990)	0.014495067472230672
#   (0, 6985)	0.05614419261764604
#   (0, 6983)	0.018462126900691832
#   (0, 6978)	0.02570126277514359
#   (0, 6953)	0.041040446075474774
#   (0, 6928)	0.021083158514245675
#   (0, 6927)	0.022800124584703946
#   (0, 6845)	0.04529282661236908
#   (0, 6824)	0.04529282661236908
#   (0, 6740)	0.18219672162077524
#   (0, 6739)	0.06347026993336576
#   (0, 6738)	0.09068830341053319
#   (0, 6699)	0.0340400803211732
#   :	:
#   (961, 1634)	0.0483246284265704
#   (961, 1442)	0.014243638406091599
#   (961, 1394)	0.0543835808798097
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(requiredtext, df['Category'], test_size=0.2, random_state=42)

# %% [markdown]
# ## Model 1 - KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# Initialize the model
knn = KNeighborsClassifier()

# Train the model
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
model_knn = knn.predict(X_test)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:110: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\ProgramData\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 199, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\ProgramData\anaconda3\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\ProgramData\anaconda3\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\ProgramData\anaconda3\Lib\subprocess.py", line 1538, in _execute_child
# ...

# %%
print(model_knn)
# Out:
# [15 15 15 13 14 17 16  2  0 14 13 12 16 23 20  5  6  4 10  9 19  1 10 23
#  23 21 22 22  2 12 18  1  8 24 11 23  7 12 24  8 18  6  8 19 24 23 21  1
#  15  4 15 22 11  5 15 13  1 19  5 12 22 22 20 24 21 18 12 10 10 20 10  8
#   9 21 17 21  0 17 16 14 15 11 11  8 20  3 19  8  0  2  9 10  2 23 20 20
#  23 12 18 12  7 16  8 14 18  3 14 19 14 14 15 18  8  2 21 18 23 10 23  5
#  11 15 12  3  5  3  7 12 19  8 20 19  3 15  9 19  1 23 21  5 20 15 16  7
#   7  8 15 18  1 15 13 20  7  4 18 11  5 15  5 12  9 22 18 21  8 23  4 12
#  24 16 15 22  8 22  3 16 23 23 12  7 16 18  5  3 18  8 23 23 20 21  6  7
#  23]

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, model_knn))
# Out:
# Accuracy: 0.9844559585492227

# %%
# Pickling
import pickle

pickle.dump(tfidf, open('tfidf_knn.pkl', 'wb'))
pickle.dump(knn, open('model_knn.pkl', 'wb'))

# %%
resume = """ working as data Scientist with PYTHON, SQL, POWER BI """

x = pickle.load(open('model_knn.pkl', 'rb'))
cleaned_resume = cleanResume(resume)
input_features = tfidf.transform([cleaned_resume])
prediction_id = x.predict(input_features)[0]


category_mapping = {
            8: "DevOps Engineer",
            23: "Testing",
            15: "Data Analyst",
            20: "Python Developer",
            24: "Web Designing",
            12: "HR",
            13: "Hadoop",
            3: "Blockchain",
            10: "ETL Developer",
            18: "Operations Manager",
            6: "Data Science",
            22: "Sales",
            16: "Mechanical Engineer",
            1: "Arts",
            7: "Database",
            11: "Electrical Engineering",
            14: "Health and fitness",
            19: "PMO",
            4: "Business Analyst",
            9: "DotNet Developer",
            2: "Automation Testing",
            17: "Network Security Engineer",
            21: "SAP Developer",
            5: "Civil Engineer",
            0: "Advocate"
}

category_name = category_mapping.get(prediction_id)
print("The resume belongs to the category of", category_name)
# Out:
# The resume belongs to the category of Data Science

# %%
# Example resume classification
resume = """ This us the resume of a candidate who analysis the data and findout the useful insights and visualize in tools like power bi and tableau """

#resume = """ working as data Scientist with PYTHON, SQL, POWER BI """
loaded_model = pickle.load(open('model_knn.pkl', 'rb'))
cleaned_resume = cleanResume(resume)
input_features = tfidf.transform([cleaned_resume])
prediction_id = loaded_model.predict(input_features)[0]

# Mapping the prediction to category names
category_mapping = {
    8: "DevOps Engineer",
    23: "Testing",
    15: "Data Analyst",
    20: "Python Developer",
    24: "Web Designing",
    12: "HR",
    13: "Hadoop",
    3: "Blockchain",
    10: "java Developer",
    18: "Operations Manager",
    6: "Data Science",
    22: "Sales",
    16: "Mechanical Engineer",
    1: "Arts",
    7: "Database",
    11: "Electrical Engineering",
    14: "Health and fitness",
    19: "PMO",
    4: "Business Analyst",
    9: "DotNet Developer",
    2: "Automation Testing",
    17: "Network Security Engineer",
    21: "SAP Developer",
    5: "Civil Engineer",
    0: "Advocate"
}

# Print the predicted category
category_name = category_mapping.get(prediction_id, "Unknown Category")
print("The resume belongs to the category of", category_name)
# Out:
# The resume belongs to the category of Data Science

# %%
# Example resume classification
resume = """ This is the resume of a candidate who do python programming """

#resume = """ working as data Scientist with PYTHON, SQL, POWER BI """
loaded_model = pickle.load(open('model_knn.pkl', 'rb'))
cleaned_resume = cleanResume(resume)
input_features = tfidf.transform([cleaned_resume])
prediction_id = loaded_model.predict(input_features)[0]

# Mapping the prediction to category names
category_mapping = {
    8: "DevOps Engineer",
    23: "Testing",
    15: "Data Analyst",
    20: "Python Developer",
    24: "Web Designing",
    12: "HR",
    13: "Hadoop",
    3: "Blockchain",
    10: "java Developer",
    18: "Operations Manager",
    6: "Data Science",
    22: "Sales",
    16: "Mechanical Engineer",
    1: "Arts",
    7: "Database",
    11: "Electrical Engineering",
    14: "Health and fitness",
    19: "PMO",
    4: "Business Analyst",
    9: "DotNet Developer",
    2: "Automation Testing",
    17: "Network Security Engineer",
    21: "SAP Developer",
    5: "Civil Engineer",
    0: "Advocate"
}

# Print the predicted category
category_name = category_mapping.get(prediction_id, "Unknown Category")
print("The resume belongs to the category of", category_name)
# Out:
# The resume belongs to the category of Python Developer

# %% [markdown]
# ## Model 2 - MultinomialNB (naive bayes)

# %%
from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()
nb.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
model_nb = nb.predict(X_test)

# %%
print(model_nb)
# Out:
# [15 15 15 13 14 17 16  2 15 14 13 12 16 23 20  5  6  4 10  9 19  1 10 23
#  23  6 22 22  2 12 18  1  8 24 11 23  7 12 24  8 18  6  8 19 24 23 21  1
#  15  4 15 22 11  5 15 13  1 19  5 12 22 22 20 24 21 18 12 10 10 20 10  8
#   9 21 17 21  0 17 16 14 15 11 11  8 20  3 19  8 15  2  9 10  2 23 20 20
#  23 15 18 12  7 16  8 14 18  3 14 19 14 14 15 18  8  2 21 18 23 10 23 23
#  11 15 12  3 23  3  7 12 19  8 20 19  3 15  9 19  1 23 21  5 20 15 16  7
#   7  8 15 18  1 15 13 20  7  4 18 11 23 15  5 12  9 22 18 21  8 23  4 12
#  24 16 15 22  8 22  3 16 23 23 12  7 16 18  5  3 18  8 23 23 20  6  6  7
#  23]

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, model_nb))
# Out:
# Accuracy: 0.9637305699481865

# %%
# Pickling
import pickle

pickle.dump(tfidf, open('tfidf_nb.pkl', 'wb'))
pickle.dump(nb, open('model_nb.pkl', 'wb'))

# %%
# Example resume classification
resume = """ This is the resume of a candidate who do python programming """

#resume = """ working as data Scientist with PYTHON, SQL, POWER BI """
loaded_model = pickle.load(open('model_nb.pkl', 'rb'))
cleaned_resume = cleanResume(resume)
input_features = tfidf.transform([cleaned_resume])
prediction_id = loaded_model.predict(input_features)[0]

# Mapping the prediction to category names
category_mapping = {
    8: "DevOps Engineer",
    23: "Testing",
    15: "Data Analyst",
    20: "Python Developer",
    24: "Web Designing",
    12: "HR",
    13: "Hadoop",
    3: "Blockchain",
    10: "java Developer",
    18: "Operations Manager",
    6: "Data Science",
    22: "Sales",
    16: "Mechanical Engineer",
    1: "Arts",
    7: "Database",
    11: "Electrical Engineering",
    14: "Health and fitness",
    19: "PMO",
    4: "Business Analyst",
    9: "DotNet Developer",
    2: "Automation Testing",
    17: "Network Security Engineer",
    21: "SAP Developer",
    5: "Civil Engineer",
    0: "Advocate"
}

# Print the predicted category
category_name = category_mapping.get(prediction_id, "Unknown Category")
print("The resume belongs to the category of", category_name)
# Out:
# The resume belongs to the category of Python Developer

# %%
# Example resume classification
resume = """ This is the resume of a candidate who test softwares """

#resume = """ working as data Scientist with PYTHON, SQL, POWER BI """
loaded_model = pickle.load(open('model_nb.pkl', 'rb'))
cleaned_resume = cleanResume(resume)
input_features = tfidf.transform([cleaned_resume])
prediction_id = loaded_model.predict(input_features)[0]

# Mapping the prediction to category names
category_mapping = {
    8: "DevOps Engineer",
    23: "Testing",
    15: "Data Analyst",
    20: "Python Developer",
    24: "Web Designing",
    12: "HR",
    13: "Hadoop",
    3: "Blockchain",
    10: "java Developer",
    18: "Operations Manager",
    6: "Data Science",
    22: "Sales",
    16: "Mechanical Engineer",
    1: "Arts",
    7: "Database",
    11: "Electrical Engineering",
    14: "Health and fitness",
    19: "PMO",
    4: "Business Analyst",
    9: "DotNet Developer",
    2: "Automation Testing",
    17: "Network Security Engineer",
    21: "SAP Developer",
    5: "Civil Engineer",
    0: "Advocate"
}

# Print the predicted category
category_name = category_mapping.get(prediction_id, "Unknown Category")
print("The resume belongs to the category of", category_name)
# Out:
# The resume belongs to the category of Testing

# %% [markdown]
# ## Model 3 - Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
# Initialize the model
lr = LogisticRegression()

# Train the model
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Prediction
model_lr = lr.predict(X_test)
print(model_lr)
# Out:
# [15 15 15 13 14 17 16  2  0 14 13 12 16 23 20  5  6  4 10  9 19  1 10 23
#  23  6 22 22  2 12 18  1  8 24 11 23  7 12 24  8 18  6  8 19 24 23 21  1
#  15  4 15 22 11  5 15 13  1 19  5 12 22 22 20 24 21 18 12 10 10 20 10  8
#   9 21 17 21  0 17 16 14 15 11 11  8 20  3 19  8  0  2  9 10  2 23 20 20
#  23 12 18 12  7 16  8 14 18  3 14 19 14 14 15 18  8  2 21 18 23 10 23  5
#  11 15 12  3  5  3  7 12 19  8 20 19  3 15  9 19  1 23 21  5 20 15 16  7
#   7  8 15 18  1 15 13 20  7  4 18 11  5 15  5 12  9 22 18 21  8 23  4 12
#  24 16 15 22  8 22  3 16 23 23 12  7 16 18  5  3 18  8 23 23 20  6  6  7
#  23]

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, model_lr))
# Out:
# Accuracy: 0.9948186528497409

# %%
# Pickling
import pickle

pickle.dump(tfidf, open('tfidf_lr.pkl', 'wb'))
pickle.dump(lr, open('model_lr.pkl', 'wb'))

# %%
resume = """ working as general manager in operations """

x = pickle.load(open('model_lr.pkl', 'rb'))
cleaned_resume = cleanResume(resume)
input_features = tfidf.transform([cleaned_resume])
prediction_id = x.predict(input_features)[0]


category_mapping = {
            8: "DevOps Engineer",
            23: "Testing",
            15: "Data Analyst",
            20: "Python Developer",
            24: "Web Designing",
            12: "HR",
            13: "Hadoop",
            3: "Blockchain",
            10: "ETL Developer",
            18: "Operations Manager",
            6: "Data Science",
            22: "Sales",
            16: "Mechanical Engineer",
            1: "Arts",
            7: "Database",
            11: "Electrical Engineering",
            14: "Health and fitness",
            19: "PMO",
            4: "Business Analyst",
            9: "DotNet Developer",
            2: "Automation Testing",
            17: "Network Security Engineer",
            21: "SAP Developer",
            5: "Civil Engineer",
            0: "Advocate"
}

category_name = category_mapping.get(prediction_id)
print("The resume belongs to the category of", category_name)
# Out:
# The resume belongs to the category of Operations Manager

# %% [markdown]
# ## Model 4 : Decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
# Train the decision tree model
dtc = DecisionTreeClassifier()
# Fit the model
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Prediction
model_dtc = dtc.predict(X_test)
print(model_dtc)
# Out:
# [15 15 15 13 14 17 16  2  0 14 13 12 16 23 20  5  6  4 10  9 19  1 10 23
#  23  6 22 22  2 12 18  1  8 24 11 23  7 12 24  8 18  6  8 19 24 23 21  1
#  15  4 15 22 11  5 15 13  1 19  5 12 22 22 20 24 21 18 12 10 10 20 10  8
#   9 21 17 21  0 17 16 14 15 11 11  8 20  3 19  8  0  2  9 10  2 23 20 20
#  23 12 18 12  7 16  8 14 18  3 14 19 14 14 15 18  8  2 21 18 23 10 23  5
#  11 15 12  3  5  3  7 12 19  8 20 23  3 15  9 19  1 23 21  5 20 15 16  7
#   7  8 15 18  1 15 13 20  7  4 18 11  5 15  5 12  9 22 18 21  8 23  4 12
#  24 16 15 22  8 22  3 16 23 23 12  7 16 18  5  3 18  8 23 23 20  6  6  7
#  23]

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, model_dtc))
# Out:
# Accuracy: 0.9948186528497409

# %%
from sklearn.metrics import classification_report
print("Classification Report:")
print(classification_report(y_test, model_dtc))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         6
#            2       1.00      1.00      1.00         5
#            3       1.00      1.00      1.00         7
#            4       1.00      1.00      1.00         4
#            5       1.00      1.00      1.00         9
#            6       1.00      1.00      1.00         5
#            7       1.00      1.00      1.00         8
#            8       1.00      0.93      0.96        14
#            9       1.00      1.00      1.00         5
#           10       1.00      1.00      1.00         7
#           11       1.00      1.00      1.00         6
#           12       1.00      1.00      1.00        12
#           13       1.00      1.00      1.00         4
#           14       1.00      1.00      1.00         7
#           15       1.00      1.00      1.00        15
# ...

# %%
# Pickling
import pickle

pickle.dump(tfidf, open('tfidf_dtc.pkl', 'wb'))
pickle.dump(dtc, open('model_dtc.pkl', 'wb'))

# %%
resume = """ im a Civil engineer and working at construction field """

x = pickle.load(open('model_lr.pkl', 'rb'))
cleaned_resume = cleanResume(resume)
input_features = tfidf.transform([cleaned_resume])
prediction_id = x.predict(input_features)[0]


category_mapping = {
            8: "DevOps Engineer",
            23: "Testing",
            15: "Data Analyst",
            20: "Python Developer",
            24: "Web Designing",
            12: "HR",
            13: "Hadoop",
            3: "Blockchain",
            10: "ETL Developer",
            18: "Operations Manager",
            6: "Data Science",
            22: "Sales",
            16: "Mechanical Engineer",
            1: "Arts",
            7: "Database",
            11: "Electrical Engineering",
            14: "Health and fitness",
            19: "PMO",
            4: "Business Analyst",
            9: "DotNet Developer",
            2: "Automation Testing",
            17: "Network Security Engineer",
            21: "SAP Developer",
            5: "Civil Engineer",
            0: "Advocate"
}

category_name = category_mapping.get(prediction_id)
print("The resume belongs to the category of", category_name)
# Out:
# The resume belongs to the category of Civil Engineer

# %% [markdown]
# # Model 5 : Random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
# Initilize the model
rfc = RandomForestClassifier()
# Fit the model
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Prediction
model_rfc = rfc.predict(X_test)
print(model_rfc)
# Out:
# [15 15 15 13 14 17 16  2  0 14 13 12 16 23 20  5  6  4 10  9 19  1 10 23
#  23  6 22 22  2 12 18  1  8 24 11 23  7 12 24  8 18  6  8 19 24 23 21  1
#  15  4 15 22 11  5 15 13  1 19  5 12 22 22 20 24 21 18 12 10 10 20 10  8
#   9 21 17 21  0 17 16 14 15 11 11  8 20  3 19  8  0  2  9 10  2 23 20 20
#  23 12 18 12  7 16  8 14 18  3 14 19 14 14 15 18  8  2 21 18 23 10 23  5
#  11 15 12  3  5  3  7 12 19  8 20  4  3 15  9 19  1 23 21  5 20 15 16  7
#   7  8 15 18  1 15 13 20  7  4 18 11  5 15  5 12  9 22 18 21  8 23  4 12
#  24 16 15 22  8 22  3 16 23 23 12  7 16 18  5  3 18  8 23 23 20  6  6  7
#  23]

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, model_rfc))
# Out:
# Accuracy: 0.9948186528497409

# %%
from sklearn.metrics import classification_report
print("Classification Report:")
print(classification_report(y_test, model_rfc))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         6
#            2       1.00      1.00      1.00         5
#            3       1.00      1.00      1.00         7
#            4       0.80      1.00      0.89         4
#            5       1.00      1.00      1.00         9
#            6       1.00      1.00      1.00         5
#            7       1.00      1.00      1.00         8
#            8       1.00      0.93      0.96        14
#            9       1.00      1.00      1.00         5
#           10       1.00      1.00      1.00         7
#           11       1.00      1.00      1.00         6
#           12       1.00      1.00      1.00        12
#           13       1.00      1.00      1.00         4
#           14       1.00      1.00      1.00         7
#           15       1.00      1.00      1.00        15
# ...

# %%
# Pickling
import pickle

pickle.dump(tfidf, open('tfidf_rfc.pkl', 'wb'))
pickle.dump(rfc, open('model_rfc.pkl', 'wb'))

# %%
resume = """ Iam a Network security engineer and i have 5 years of experience in Network security. """

x = pickle.load(open('model_lr.pkl', 'rb'))
cleaned_resume = cleanResume(resume)
input_features = tfidf.transform([cleaned_resume])
prediction_id = x.predict(input_features)[0]


category_mapping = {
            8: "DevOps Engineer",
            23: "Testing",
            15: "Data Analyst",
            20: "Python Developer",
            24: "Web Designing",
            12: "HR",
            13: "Hadoop",
            3: "Blockchain",
            10: "ETL Developer",
            18: "Operations Manager",
            6: "Data Science",
            22: "Sales",
            16: "Mechanical Engineer",
            1: "Arts",
            7: "Database",
            11: "Electrical Engineering",
            14: "Health and fitness",
            19: "PMO",
            4: "Business Analyst",
            9: "DotNet Developer",
            2: "Automation Testing",
            17: "Network Security Engineer",
            21: "SAP Developer",
            5: "Civil Engineer",
            0: "Advocate"
}

category_name = category_mapping.get(prediction_id)
print("The resume belongs to the category of", category_name)
# Out:
# The resume belongs to the category of Network Security Engineer

# %%
from sklearn.metrics import accuracy_score

# Initialize models with specific variable names
model_knn = KNeighborsClassifier()
model_nb = MultinomialNB()
model_lr = LogisticRegression(max_iter=200)
model_dtc = DecisionTreeClassifier()
model_rf = RandomForestClassifier()

# Train models and calculate accuracies
accuracies = {}

# KNN
model_knn.fit(X_train, y_train)
model_knn = knn.predict(X_test)
accuracies['KNN'] = accuracy_score(y_test, model_knn)
#print("          KNN Accuracy :",metrics.accuracy_score(y_test, model_knn))

# MultinomialNB
model_nb.fit(X_train, y_train)
model_nb = nb.predict(X_test)
accuracies['MultinomialNB'] = accuracy_score(y_test, model_nb)
# print("MultinomialNB Accuracy :",metrics.accuracy_score(y_test, model_nb))

# Logistic Regression
model_lr.fit(X_train, y_train)
model_lr = lr.predict(X_test)
accuracies['Logistic Regression'] = accuracy_score(y_test, model_lr)
# print("Logistic Regression Accuracy :",metrics.accuracy_score(y_test, model_lr))

# Decision Tree
model_dtc.fit(X_train, y_train)
model_dtc = dtc.predict(X_test)
accuracies['Decision Tree'] = accuracy_score(y_test, model_dtc)
#print(" Decision Tree Accuracy :",metrics.accuracy_score(y_test, model_dtc))


# Random Forest
rfc.fit(X_train, y_train)
accuracies['Random Forest'] = accuracy_score(y_test, model_rfc)
# Prediction
#model_rfc = rfc.predict(X_test)
#print(" Random forest Accuracy :",metrics.accuracy_score(y_test, model_rfc))

# Convert the accuracies dictionary to a DataFrame
accuracy_df = pd.DataFrame(list(accuracies.items()), columns=['Model', 'Accuracy'])

# Display the accuracies in a table
print(accuracy_df)
# Out:
#                  Model  Accuracy
# 0                  KNN  0.984456
# 1        MultinomialNB  0.963731
# 2  Logistic Regression  0.994819
# 3        Decision Tree  0.994819
# 4        Random Forest  0.994819

# %% [markdown]
# ## Every model is working and predicting well whereas Logistic Regression,  Decision Tree and Random Forest giving approx 100% accuracy
